# %%
import langgraph
print(langgraph.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import langgraph
# ----> 2 print(langgraph.__version__)
#
# AttributeError: module 'langgraph' has no attribute '__version__'

# %%
# !pip show langgraph
# Out:
# Name: langgraph
# Version: 1.2.0
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page:
# Author:
# Author-email:
# License:
# Location: C:\Users\Kumar\AppData\Roaming\Python\Python311\site-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, pydantic, xxhash
# Required-by: langchain, langchain-google-community
